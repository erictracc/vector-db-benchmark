# %% [markdown]
# # postgresql_connection
#
# Press Double Shift to search everywhere for classes, files, tool windows, actions, and settings.
#
# To learn more about Jupyter Notebooks in PyCharm, see [help](https://www.jetbrains.com/help/pycharm/ipython-notebook-support.html).
# For an overview of PyCharm, go to Help -> Learn IDE features or refer to [our documentation](https://www.jetbrains.com/help/pycharm/getting-started.html).

# %%
# Install the PostgreSQL adapter for Python
# !pip install psycopg2-binary sentence-transformers
# Out:
# Collecting psycopg2-binary
#   Downloading psycopg2_binary-2.9.10-cp313-cp313-win_amd64.whl.metadata (4.8 kB)
# Requirement already satisfied: sentence-transformers in c:\users\erict\pycharmprojects\vector-db-research-project\.venv\lib\site-packages (5.1.0)
# Requirement already satisfied: transformers<5.0.0,>=4.41.0 in c:\users\erict\pycharmprojects\vector-db-research-project\.venv\lib\site-packages (from sentence-transformers) (4.56.1)
# Requirement already satisfied: tqdm in c:\users\erict\pycharmprojects\vector-db-research-project\.venv\lib\site-packages (from sentence-transformers) (4.67.1)
# Requirement already satisfied: torch>=1.11.0 in c:\users\erict\pycharmprojects\vector-db-research-project\.venv\lib\site-packages (from sentence-transformers) (2.8.0)
# Requirement already satisfied: scikit-learn in c:\users\erict\pycharmprojects\vector-db-research-project\.venv\lib\site-packages (from sentence-transformers) (1.7.2)
# Requirement already satisfied: scipy in c:\users\erict\pycharmprojects\vector-db-research-project\.venv\lib\site-packages (from sentence-transformers) (1.16.2)
# Requirement already satisfied: huggingface-hub>=0.20.0 in c:\users\erict\pycharmprojects\vector-db-research-project\.venv\lib\site-packages (from sentence-transformers) (0.34.4)
# Requirement already satisfied: Pillow in c:\users\erict\pycharmprojects\vector-db-research-project\.venv\lib\site-packages (from sentence-transformers) (11.3.0)
# Requirement already satisfied: typing_extensions>=4.5.0 in c:\users\erict\pycharmprojects\vector-db-research-project\.venv\lib\site-packages (from sentence-transformers) (4.15.0)
# Requirement already satisfied: filelock in c:\users\erict\pycharmprojects\vector-db-research-project\.venv\lib\site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (3.19.1)
# Requirement already satisfied: numpy>=1.17 in c:\users\erict\pycharmprojects\vector-db-research-project\.venv\lib\site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (2.3.3)
# Requirement already satisfied: packaging>=20.0 in c:\users\erict\pycharmprojects\vector-db-research-project\.venv\lib\site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\erict\pycharmprojects\vector-db-research-project\.venv\lib\site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in c:\users\erict\pycharmprojects\vector-db-research-project\.venv\lib\site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (2025.9.1)
# Requirement already satisfied: requests in c:\users\erict\pycharmprojects\vector-db-research-project\.venv\lib\site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (2.32.5)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in c:\users\erict\pycharmprojects\vector-db-research-project\.venv\lib\site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (0.22.0)
# Requirement already satisfied: safetensors>=0.4.3 in c:\users\erict\pycharmprojects\vector-db-research-project\.venv\lib\site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (0.6.2)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\erict\pycharmprojects\vector-db-research-project\.venv\lib\site-packages (from huggingface-hub>=0.20.0->sentence-transformers) (2025.9.0)
# Requirement already satisfied: sympy>=1.13.3 in c:\users\erict\pycharmprojects\vector-db-research-project\.venv\lib\site-packages (from torch>=1.11.0->sentence-transformers) (1.14.0)
# Requirement already satisfied: networkx in c:\users\erict\pycharmprojects\vector-db-research-project\.venv\lib\site-packages (from torch>=1.11.0->sentence-transformers) (3.5)
# Requirement already satisfied: jinja2 in c:\users\erict\pycharmprojects\vector-db-research-project\.venv\lib\site-packages (from torch>=1.11.0->sentence-transformers) (3.1.6)
# Requirement already satisfied: setuptools in c:\users\erict\pycharmprojects\vector-db-research-project\.venv\lib\site-packages (from torch>=1.11.0->sentence-transformers) (80.9.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\erict\pycharmprojects\vector-db-research-project\.venv\lib\site-packages (from sympy>=1.13.3->torch>=1.11.0->sentence-transformers) (1.3.0)
# Requirement already satisfied: colorama in c:\users\erict\pycharmprojects\vector-db-research-project\.venv\lib\site-packages (from tqdm->sentence-transformers) (0.4.6)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\erict\pycharmprojects\vector-db-research-project\.venv\lib\site-packages (from jinja2->torch>=1.11.0->sentence-transformers) (3.0.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\erict\pycharmprojects\vector-db-research-project\.venv\lib\site-packages (from requests->transformers<5.0.0,>=4.41.0->sentence-transformers) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\erict\pycharmprojects\vector-db-research-project\.venv\lib\site-packages (from requests->transformers<5.0.0,>=4.41.0->sentence-transformers) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\erict\pycharmprojects\vector-db-research-project\.venv\lib\site-packages (from requests->transformers<5.0.0,>=4.41.0->sentence-transformers) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\erict\pycharmprojects\vector-db-research-project\.venv\lib\site-packages (from requests->transformers<5.0.0,>=4.41.0->sentence-transformers) (2025.8.3)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\erict\pycharmprojects\vector-db-research-project\.venv\lib\site-packages (from scikit-learn->sentence-transformers) (1.5.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\erict\pycharmprojects\vector-db-research-project\.venv\lib\site-packages (from scikit-learn->sentence-transformers) (3.6.0)
# Downloading psycopg2_binary-2.9.10-cp313-cp313-win_amd64.whl (2.6 MB)
#    ---------------------------------------- 0.0/2.6 MB ? eta -:--:--
#    ---------------------------------------- 2.6/2.6 MB 23.5 MB/s eta 0:00:00
# Installing collected packages: psycopg2-binary
# Successfully installed psycopg2-binary-2.9.10
# [notice] A new release of pip is available: 25.1.1 -> 25.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import os
import psycopg2
from psycopg2.extras import execute_values
from dotenv import load_dotenv

# Load environment variables from .env
load_dotenv()

# Retrieve credentials from the .env file
db_params = {
    "host": os.getenv("PG_HOST"),
    "port": os.getenv("PG_PORT"),
    "database": os.getenv("PG_DB"),
    "user": os.getenv("PG_USER"),
    "password": os.getenv("PG_PASSWORD")
}

# Connect to PostgreSQL and create the pgvector table
conn = None
try:
    conn = psycopg2.connect(**db_params)
    cursor = conn.cursor()
    print("✓ Successfully connected to PostgreSQL!")

    # Enable the pgvector extension
    cursor.execute("CREATE EXTENSION IF NOT EXISTS vector;")
    print("✓ Vector extension enabled.")

    # Create a table with a vector column for embeddings (dimension 384)
    create_table_query = """
    CREATE TABLE IF NOT EXISTS documents (
        id BIGSERIAL PRIMARY KEY,
        content TEXT,
        embedding vector(384)
    );
    """
    cursor.execute(create_table_query)
    conn.commit()
    print("✓ Table 'documents' created successfully (or already exists).")

except psycopg2.Error as e:
    print(f"✗ Error connecting to PostgreSQL: {e}")

finally:
    if conn:
        cursor.close()
        conn.close()
        print("Connection closed.")
# Out:
# ✓ Successfully connected to PostgreSQL!
# ✓ Vector extension enabled.
# ✓ Table 'documents' created successfully (or already exists).
# Connection closed.

# %%
# Re-establish connection for a new operation
conn = psycopg2.connect(**db_params)
cursor = conn.cursor()

# Insert a test record
insert_query = "INSERT INTO documents (content) VALUES (%s) RETURNING id;"
cursor.execute(insert_query, ("Hello, World! This is my first PostgreSQL document.",))
# Get the ID of the newly inserted record
new_id = cursor.fetchone()[0]

conn.commit()
print(f"✓ Inserted document with id: {new_id}")

cursor.close()
conn.close()
# Out:
# ✓ Inserted document with id: 1

# %%
# ### CLEANUP CELL - Use this to reset your table
conn = psycopg2.connect(**db_params)
conn.autocommit = True # Needed for DROP operations
cursor = conn.cursor()

# This will delete the table and all its data
cursor.execute("DROP TABLE IF EXISTS documents;")
print("Table 'documents' dropped.")

cursor.close()
conn.close()
# Out:
# Table 'documents' dropped.
